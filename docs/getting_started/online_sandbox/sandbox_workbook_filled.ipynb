# %% [markdown]
# # Online Sandbox Tutorial

# %% [markdown]
# # Setting Up
# We will first need to install the package, as Google Colab's default environment doesn't have the chainladder package pre-installed.
#
# Simply execute `pip install chainladder`, Colab is smart enough to know that this is not a piece of python code, but to execute it in shell. FYI, `pip` stands for "Package Installer for Python". You will need to run this step using your terminal instead of using a python notebook when you are ready to install the package on your machine.

# %%
pip install chainladder
# Out:
# Requirement already satisfied: chainladder in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (0.8.24)
# Requirement already satisfied: pandas>=2.0 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from chainladder) (2.2.3)
# Requirement already satisfied: scikit-learn>1.4.2 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from chainladder) (1.6.1)
# Requirement already satisfied: numba>0.54 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from chainladder) (0.60.0)
# Requirement already satisfied: sparse>=0.9 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from chainladder) (0.14.0)
# Requirement already satisfied: matplotlib in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from chainladder) (3.9.2)
# Requirement already satisfied: dill in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from chainladder) (0.3.5.1)
# Requirement already satisfied: patsy in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from chainladder) (0.5.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from numba>0.54->chainladder) (0.43.0)
# Requirement already satisfied: numpy<2.1,>=1.22 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from numba>0.54->chainladder) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from pandas>=2.0->chainladder) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from pandas>=2.0->chainladder) (2022.6)
# Requirement already satisfied: tzdata>=2022.7 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from pandas>=2.0->chainladder) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=2.0->chainladder) (1.17.0)
# Requirement already satisfied: scipy>=1.6.0 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>1.4.2->chainladder) (1.10.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>1.4.2->chainladder) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>1.4.2->chainladder) (3.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->chainladder) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->chainladder) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->chainladder) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->chainladder) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->chainladder) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->chainladder) (9.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->chainladder) (3.2.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->chainladder) (5.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->chainladder) (3.10.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Other commonly used packages, such as `numpy`, `pandas`, and `matplotlib` are already pre-installed, we just need to load them into our environment.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import chainladder as cl

print("chainladder", cl.__version__)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# chainladder 0.8.24

# %% [markdown]
# # Your Journey Begins

# %% [markdown]
# Let's begin by looking at a sample dataset, called `xyz`, which is hosted on https://raw.githubusercontent.com/casact/chainladder-python/master/chainladder/utils/data/xyz.csv.
#
# Let's load the dataset into the memory with `pandas`, then inspect its "`head`".

# %%
xyz_df = pd.read_csv(
    "https://raw.githubusercontent.com/casact/chainladder-python/master/chainladder/utils/data/xyz.csv"
)
xyz_df.head()
# Out:
#    AccidentYear  DevelopmentYear  Incurred  Paid  Reported  Closed  Premium
# 0          2002             2002     12811  2318      1342     203    61183
# 1          2003             2003      9651  1743      1373     181    69175
# 2          2004             2004     16995  2221      1932     235    99322
# 3          2005             2005     28674  3043      2067     295   138151
# 4          2006             2006     27066  3531      1473     307   107578

# %% [markdown]
# Can you list all of the unique accident years?

# %%
xyz_df["AccidentYear"].unique()
# Out:
# array([2002, 2003, 2004, 2005, 2006, 2007, 2008, 1998, 1999, 2000, 2001])

# %% [markdown]
# How many are there?

# %%
xyz_df["AccidentYear"].nunique()
# Out:
# 11

# %% [markdown]
# # Triangle Basics

# %% [markdown]
# Let's load the data into the chainladder triangle format. And let's call it `xyz_tri`.

# %%
xyz_tri = cl.Triangle(
    data=xyz_df,
    origin="AccidentYear",
    development="DevelopmentYear",
    columns=["Incurred", "Paid", "Reported", "Closed", "Premium"],
    cumulative=True,
)
xyz_tri
# Out:
#                                        Triangle Summary
# Valuation:                                      2008-12
# Grain:                                             OYDY
# Shape:                                   (1, 5, 11, 11)
# Index:                                          [Total]
# Columns:    [Incurred, Paid, Reported, Closed, Premium]

# %% [markdown]
# What does the incurred triangle look like?

# %%
xyz_tri["Incurred"]
# Out:
#           12       24       36       48       60       72       84       96       108      120      132
# 1998      NaN      NaN  11171.0  12380.0  13216.0  14067.0  14688.0  16366.0  16163.0  15835.0  15822.0
# 1999      NaN  13255.0  16405.0  19639.0  22473.0  23764.0  25094.0  24795.0  25071.0  25107.0      NaN
# 2000  15676.0  18749.0  21900.0  27144.0  29488.0  34458.0  36949.0  37505.0  37246.0      NaN      NaN
# 2001  11827.0  16004.0  21022.0  26578.0  34205.0  37136.0  38541.0  38798.0      NaN      NaN      NaN
# 2002  12811.0  20370.0  26656.0  37667.0  44414.0  48701.0  48169.0      NaN      NaN      NaN      NaN
# 2003   9651.0  16995.0  30354.0  40594.0  44231.0  44373.0      NaN      NaN      NaN      NaN      NaN
# 2004  16995.0  40180.0  58866.0  71707.0  70288.0      NaN      NaN      NaN      NaN      NaN      NaN
# 2005  28674.0  47432.0  70340.0  70655.0      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2006  27066.0  46783.0  48804.0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2007  19477.0  31732.0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2008  18632.0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN

# %% [markdown]
# How about paid?

# %%
xyz_tri["Paid"]
# Out:
#          12       24       36       48       60       72       84       96       108      120      132
# 1998     NaN      NaN   6309.0   8521.0  10082.0  11620.0  13242.0  14419.0  15311.0  15764.0  15822.0
# 1999     NaN   4666.0   9861.0  13971.0  18127.0  22032.0  23511.0  24146.0  24592.0  24817.0      NaN
# 2000  1302.0   6513.0  12139.0  17828.0  24030.0  28853.0  33222.0  35902.0  36782.0      NaN      NaN
# 2001  1539.0   5952.0  12319.0  18609.0  24387.0  31090.0  37070.0  38519.0      NaN      NaN      NaN
# 2002  2318.0   7932.0  13822.0  22095.0  31945.0  40629.0  44437.0      NaN      NaN      NaN      NaN
# 2003  1743.0   6240.0  12683.0  22892.0  34505.0  39320.0      NaN      NaN      NaN      NaN      NaN
# 2004  2221.0   9898.0  25950.0  43439.0  52811.0      NaN      NaN      NaN      NaN      NaN      NaN
# 2005  3043.0  12219.0  27073.0  40026.0      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2006  3531.0  11778.0  22819.0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2007  3529.0  11865.0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2008  3409.0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN

# %% [markdown]
# # Pandas-like Operations

# %% [markdown]
# Let's see how `.iloc[...]` and `.loc[...]` similarly to pandas. They take 4 parameters: [index, column, origin, valuation].

# %% [markdown]
# What if we want the row from AY 1998 Incurred data?

# %%
xyz_tri.iloc[:, 0, 0, :]
# Out:
#       12   24       36       48       60       72       84       96       108      120      132
# 1998  NaN  NaN  11171.0  12380.0  13216.0  14067.0  14688.0  16366.0  16163.0  15835.0  15822.0

# %% [markdown]
# What if you only want the valuation at age 60 of AY 1998?

# %%
xyz_tri.iloc[:, 0, 0, 4]
# Out:
#            60
# 1998  13216.0

# %% [markdown]
# Let's use `.loc[...]` to get the incurred triangle.

# %%
xyz_tri.loc[:, "Incurred", :, :]
# Out:
#           12       24       36       48       60       72       84       96       108      120      132
# 1998      NaN      NaN  11171.0  12380.0  13216.0  14067.0  14688.0  16366.0  16163.0  15835.0  15822.0
# 1999      NaN  13255.0  16405.0  19639.0  22473.0  23764.0  25094.0  24795.0  25071.0  25107.0      NaN
# 2000  15676.0  18749.0  21900.0  27144.0  29488.0  34458.0  36949.0  37505.0  37246.0      NaN      NaN
# 2001  11827.0  16004.0  21022.0  26578.0  34205.0  37136.0  38541.0  38798.0      NaN      NaN      NaN
# 2002  12811.0  20370.0  26656.0  37667.0  44414.0  48701.0  48169.0      NaN      NaN      NaN      NaN
# 2003   9651.0  16995.0  30354.0  40594.0  44231.0  44373.0      NaN      NaN      NaN      NaN      NaN
# 2004  16995.0  40180.0  58866.0  71707.0  70288.0      NaN      NaN      NaN      NaN      NaN      NaN
# 2005  28674.0  47432.0  70340.0  70655.0      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2006  27066.0  46783.0  48804.0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2007  19477.0  31732.0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2008  18632.0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN

# %% [markdown]
# How do we get the latest Incurred diagonal only?

# %%
xyz_tri["Incurred"].latest_diagonal
# Out:
#          2008
# 1998  15822.0
# 1999  25107.0
# 2000  37246.0
# 2001  38798.0
# 2002  48169.0
# 2003  44373.0
# 2004  70288.0
# 2005  70655.0
# 2006  48804.0
# 2007  31732.0
# 2008  18632.0

# %% [markdown]
# Very often, we want incremental triangles instead. Let's convert the Incurred triangle to the incremental form.

# %%
xyz_tri["Incurred"].cum_to_incr()
# Out:
#           12       24       36       48      60      72      84      96     108    120   132
# 1998      NaN      NaN  11171.0   1209.0   836.0   851.0   621.0  1678.0 -203.0 -328.0 -13.0
# 1999      NaN  13255.0   3150.0   3234.0  2834.0  1291.0  1330.0  -299.0  276.0   36.0   NaN
# 2000  15676.0   3073.0   3151.0   5244.0  2344.0  4970.0  2491.0   556.0 -259.0    NaN   NaN
# 2001  11827.0   4177.0   5018.0   5556.0  7627.0  2931.0  1405.0   257.0    NaN    NaN   NaN
# 2002  12811.0   7559.0   6286.0  11011.0  6747.0  4287.0  -532.0     NaN    NaN    NaN   NaN
# 2003   9651.0   7344.0  13359.0  10240.0  3637.0   142.0     NaN     NaN    NaN    NaN   NaN
# 2004  16995.0  23185.0  18686.0  12841.0 -1419.0     NaN     NaN     NaN    NaN    NaN   NaN
# 2005  28674.0  18758.0  22908.0    315.0     NaN     NaN     NaN     NaN    NaN    NaN   NaN
# 2006  27066.0  19717.0   2021.0      NaN     NaN     NaN     NaN     NaN    NaN    NaN   NaN
# 2007  19477.0  12255.0      NaN      NaN     NaN     NaN     NaN     NaN    NaN    NaN   NaN
# 2008  18632.0      NaN      NaN      NaN     NaN     NaN     NaN     NaN    NaN    NaN   NaN

# %% [markdown]
# We can also convert the triangle to the valuation format, what we often see on Schedule Ps.

# %%
xyz_tri["Incurred"].dev_to_val()
# Out:
#       1998  1999     2000     2001     2002     2003     2004     2005     2006     2007     2008
# 1998   NaN   NaN  11171.0  12380.0  13216.0  14067.0  14688.0  16366.0  16163.0  15835.0  15822.0
# 1999   NaN   NaN  13255.0  16405.0  19639.0  22473.0  23764.0  25094.0  24795.0  25071.0  25107.0
# 2000   NaN   NaN  15676.0  18749.0  21900.0  27144.0  29488.0  34458.0  36949.0  37505.0  37246.0
# 2001   NaN   NaN      NaN  11827.0  16004.0  21022.0  26578.0  34205.0  37136.0  38541.0  38798.0
# 2002   NaN   NaN      NaN      NaN  12811.0  20370.0  26656.0  37667.0  44414.0  48701.0  48169.0
# 2003   NaN   NaN      NaN      NaN      NaN   9651.0  16995.0  30354.0  40594.0  44231.0  44373.0
# 2004   NaN   NaN      NaN      NaN      NaN      NaN  16995.0  40180.0  58866.0  71707.0  70288.0
# 2005   NaN   NaN      NaN      NaN      NaN      NaN      NaN  28674.0  47432.0  70340.0  70655.0
# 2006   NaN   NaN      NaN      NaN      NaN      NaN      NaN      NaN  27066.0  46783.0  48804.0
# 2007   NaN   NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN  19477.0  31732.0
# 2008   NaN   NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN  18632.0

# %% [markdown]
# Another function that is often useful is the `.heatmap()` method. Let's inspect the incurred amount and see if there are trends.

# %%
xyz_tri["Incurred"].heatmap()
# Out:
# <style type="text/css">
# #T_a544d_row0_col0, #T_a544d_row0_col1, #T_a544d_row0_col10, #T_a544d_row1_col0, #T_a544d_row1_col8, #T_a544d_row1_col10, #T_a544d_row2_col6, #T_a544d_row2_col9, #T_a544d_row2_col10, #T_a544d_row3_col4, #T_a544d_row3_col8, #T_a544d_row3_col9, #T_a544d_row3_col10, #T_a544d_row4_col1, #T_a544d_row4_col2, #T_a544d_row4_col7, #T_a544d_row4_col8, #T_a544d_row4_col9, #T_a544d_row4_col10, #T_a544d_row5_col6, #T_a544d_row5_col7, #T_a544d_row5_col8, #T_a544d_row5_col9, #T_a544d_row5_col10, #T_a544d_row6_col0, #T_a544d_row6_col5, #T_a544d_row6_col6, #T_a544d_row6_col7, #T_a544d_row6_col8, #T_a544d_row6_col9, #T_a544d_row6_col10, #T_a544d_row7_col4, #T_a544d_row7_col5, #T_a544d_row7_col6, #T_a544d_row7_col7, #T_a544d_row7_col8, #T_a544d_row7_col9, #T_a544d_row7_col10, #T_a544d_row8_col3, #T_a544d_row8_col4, #T_a544d_row8_col5, #T_a544d_row8_col6, #T_a544d_row8_col7, #T_a544d_row8_col8, #T_a544d_row8_col9, #T_a544d_row8_col10, #T_a544d_row9_col2, #T_a544d_row9_col3, #T_a544d_row9_col4, #T_a544d_row9_col5, #T_a544d_row9_col6, #T_a544d_row9_col7, #T_a544d_row9_col8, #T_a544d_row9_col9, #T_a544d_row9_col10, #T_a544d_row10_col1, #T_a544d_row10_col2, #T_a544d_row10_col3, #T_a544d_row10_col4, #T_a544d_row10_col5, #T_a544d_row10_col6, #T_a544d_row10_col7, #T_a544d_row10_col8, #T_a544d_row10_col9, #T_a544d_row10_col10 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_a544d_row0_col2, #T_a544d_row0_col3, #T_a544d_row0_col4, #T_a544d_row0_col5, #T_a544d_row0_col6, #T_a544d_row0_col7, #T_a544d_row0_col8, #T_a544d_row0_col9, #T_a544d_row1_col1, #T_a544d_row5_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a544d_row1_col2, #T_a544d_row3_col0, #T_a544d_row3_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_a544d_row1_col3 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_a544d_row1_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_a544d_row1_col5 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_a544d_row1_col6, #T_a544d_row3_col2, #T_a544d_row4_col0, #T_a544d_row5_col1 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_a544d_row1_col7, #T_a544d_row2_col4 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_a544d_row1_col9, #T_a544d_row2_col8, #T_a544d_row3_col7, #T_a544d_row4_col5, #T_a544d_row4_col6, #T_a544d_row6_col3, #T_a544d_row6_col4, #T_a544d_row7_col0, #T_a544d_row7_col1, #T_a544d_row7_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a544d_row2_col0, #T_a544d_row2_col1, #T_a544d_row2_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_a544d_row2_col3 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_a544d_row2_col5 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_a544d_row2_col7, #T_a544d_row5_col4 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_a544d_row3_col3 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_a544d_row3_col5 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_a544d_row3_col6, #T_a544d_row6_col1, #T_a544d_row8_col2, #T_a544d_row9_col0 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_a544d_row4_col3 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_a544d_row4_col4 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_a544d_row5_col2, #T_a544d_row9_col1, #T_a544d_row10_col0 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_a544d_row5_col3 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_a544d_row5_col5 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_a544d_row6_col2, #T_a544d_row8_col0, #T_a544d_row8_col1 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_a544d_row7_col3 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a544d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a544d_level0_col0" class="col_heading level0 col0" >12</th>
#       <th id="T_a544d_level0_col1" class="col_heading level0 col1" >24</th>
#       <th id="T_a544d_level0_col2" class="col_heading level0 col2" >36</th>
#       <th id="T_a544d_level0_col3" class="col_heading level0 col3" >48</th>
#       <th id="T_a544d_level0_col4" class="col_heading level0 col4" >60</th>
#       <th id="T_a544d_level0_col5" class="col_heading level0 col5" >72</th>
#       <th id="T_a544d_level0_col6" class="col_heading level0 col6" >84</th>
#       <th id="T_a544d_level0_col7" class="col_heading level0 col7" >96</th>
#       <th id="T_a544d_level0_col8" class="col_heading level0 col8" >108</th>
#       <th id="T_a544d_level0_col9" class="col_heading level0 col9" >120</th>
#       <th id="T_a544d_level0_col10" class="col_heading level0 col10" >132</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a544d_level0_row0" class="row_heading level0 row0" >1998</th>
#       <td></td>
#       <td></td>
#       <td id="T_a544d_row0_col2" class="data row0 col2" >11,171</td>
#       <td id="T_a544d_row0_col3" class="data row0 col3" >12,380</td>
#       <td id="T_a544d_row0_col4" class="data row0 col4" >13,216</td>
#       <td id="T_a544d_row0_col5" class="data row0 col5" >14,067</td>
#       <td id="T_a544d_row0_col6" class="data row0 col6" >14,688</td>
#       <td id="T_a544d_row0_col7" class="data row0 col7" >16,366</td>
#       <td id="T_a544d_row0_col8" class="data row0 col8" >16,163</td>
#       <td id="T_a544d_row0_col9" class="data row0 col9" >15,835</td>
#       <td id="T_a544d_row0_col10" class="data row0 col10" >15,822</td>
#     </tr>
#     <tr>
#       <th id="T_a544d_level0_row1" class="row_heading level0 row1" >1999</th>
#       <td></td>
#       <td id="T_a544d_row1_col1" class="data row1 col1" >13,255</td>
#       <td id="T_a544d_row1_col2" class="data row1 col2" >16,405</td>
#       <td id="T_a544d_row1_col3" class="data row1 col3" >19,639</td>
#       <td id="T_a544d_row1_col4" class="data row1 col4" >22,473</td>
#       <td id="T_a544d_row1_col5" class="data row1 col5" >23,764</td>
#       <td id="T_a544d_row1_col6" class="data row1 col6" >25,094</td>
#       <td id="T_a544d_row1_col7" class="data row1 col7" >24,795</td>
#       <td id="T_a544d_row1_col8" class="data row1 col8" >25,071</td>
#       <td id="T_a544d_row1_col9" class="data row1 col9" >25,107</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th id="T_a544d_level0_row2" class="row_heading level0 row2" >2000</th>
#       <td id="T_a544d_row2_col0" class="data row2 col0" >15,676</td>
#       <td id="T_a544d_row2_col1" class="data row2 col1" >18,749</td>
#       <td id="T_a544d_row2_col2" class="data row2 col2" >21,900</td>
#       <td id="T_a544d_row2_col3" class="data row2 col3" >27,144</td>
#       <td id="T_a544d_row2_col4" class="data row2 col4" >29,488</td>
#       <td id="T_a544d_row2_col5" class="data row2 col5" >34,458</td>
#       <td id="T_a544d_row2_col6" class="data row2 col6" >36,949</td>
#       <td id="T_a544d_row2_col7" class="data row2 col7" >37,505</td>
#       <td id="T_a544d_row2_col8" class="data row2 col8" >37,246</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th id="T_a544d_level0_row3" class="row_heading level0 row3" >2001</th>
#       <td id="T_a544d_row3_col0" class="data row3 col0" >11,827</td>
#       <td id="T_a544d_row3_col1" class="data row3 col1" >16,004</td>
#       <td id="T_a544d_row3_col2" class="data row3 col2" >21,022</td>
#       <td id="T_a544d_row3_col3" class="data row3 col3" >26,578</td>
#       <td id="T_a544d_row3_col4" class="data row3 col4" >34,205</td>
#       <td id="T_a544d_row3_col5" class="data row3 col5" >37,136</td>
#       <td id="T_a544d_row3_col6" class="data row3 col6" >38,541</td>
#       <td id="T_a544d_row3_col7" class="data row3 col7" >38,798</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th id="T_a544d_level0_row4" class="row_heading level0 row4" >2002</th>
#       <td id="T_a544d_row4_col0" class="data row4 col0" >12,811</td>
#       <td id="T_a544d_row4_col1" class="data row4 col1" >20,370</td>
#       <td id="T_a544d_row4_col2" class="data row4 col2" >26,656</td>
#       <td id="T_a544d_row4_col3" class="data row4 col3" >37,667</td>
#       <td id="T_a544d_row4_col4" class="data row4 col4" >44,414</td>
#       <td id="T_a544d_row4_col5" class

# %% [markdown]
# # Development

# %% [markdown]
# How can we get the incurred link ratios?

# %%
xyz_tri["Incurred"].link_ratio
# Out:
#          12-24     24-36     36-48     48-60     60-72     72-84     84-96    96-108   108-120   120-132
# 1998       NaN       NaN  1.108227  1.067528  1.064392  1.044146  1.114243  0.987596  0.979707  0.999179
# 1999       NaN  1.237646  1.197135  1.144305  1.057447  1.055967  0.988085  1.011131  1.001436       NaN
# 2000  1.196032  1.168062  1.239452  1.086354  1.168543  1.072291  1.015048  0.993094       NaN       NaN
# 2001  1.353175  1.313547  1.264295  1.286967  1.085689  1.037834  1.006668       NaN       NaN       NaN
# 2002  1.590040  1.308591  1.413078  1.179122  1.096524  0.989076       NaN       NaN       NaN       NaN
# 2003  1.760957  1.786055  1.337353  1.089595  1.003210       NaN       NaN       NaN       NaN       NaN
# 2004  2.364225  1.465057  1.218140  0.980211       NaN       NaN       NaN       NaN       NaN       NaN
# 2005  1.654181  1.482965  1.004478       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2006  1.728479  1.043199       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2007  1.629204       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN       NaN

# %% [markdown]
# We can also apply a `.heatmap()` to make it too, to help us visulize the highs and lows.

# %%
xyz_tri["Incurred"].link_ratio.heatmap()
# Out:
# <style type="text/css">
# #T_1064b_row0_col0, #T_1064b_row0_col1, #T_1064b_row0_col5, #T_1064b_row0_col9, #T_1064b_row1_col0, #T_1064b_row1_col9, #T_1064b_row2_col7, #T_1064b_row2_col8, #T_1064b_row2_col9, #T_1064b_row3_col7, #T_1064b_row3_col8, #T_1064b_row3_col9, #T_1064b_row4_col6, #T_1064b_row4_col7, #T_1064b_row4_col8, #T_1064b_row4_col9, #T_1064b_row5_col3, #T_1064b_row5_col5, #T_1064b_row5_col6, #T_1064b_row5_col7, #T_1064b_row5_col8, #T_1064b_row5_col9, #T_1064b_row6_col4, #T_1064b_row6_col5, #T_1064b_row6_col6, #T_1064b_row6_col7, #T_1064b_row6_col8, #T_1064b_row6_col9, #T_1064b_row7_col3, #T_1064b_row7_col4, #T_1064b_row7_col5, #T_1064b_row7_col6, #T_1064b_row7_col7, #T_1064b_row7_col8, #T_1064b_row7_col9, #T_1064b_row8_col2, #T_1064b_row8_col3, #T_1064b_row8_col4, #T_1064b_row8_col5, #T_1064b_row8_col6, #T_1064b_row8_col7, #T_1064b_row8_col8, #T_1064b_row8_col9, #T_1064b_row9_col1, #T_1064b_row9_col2, #T_1064b_row9_col3, #T_1064b_row9_col4, #T_1064b_row9_col5, #T_1064b_row9_col6, #T_1064b_row9_col7, #T_1064b_row9_col8, #T_1064b_row9_col9 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_1064b_row0_col2, #T_1064b_row2_col1, #T_1064b_row3_col0 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_1064b_row0_col3 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_1064b_row0_col4 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_1064b_row0_col6, #T_1064b_row1_col7, #T_1064b_row1_col8, #T_1064b_row2_col4, #T_1064b_row2_col5, #T_1064b_row3_col3, #T_1064b_row4_col2, #T_1064b_row5_col1, #T_1064b_row6_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1064b_row0_col7, #T_1064b_row0_col8, #T_1064b_row1_col6, #T_1064b_row2_col0, #T_1064b_row4_col5, #T_1064b_row5_col4, #T_1064b_row6_col3, #T_1064b_row7_col2, #T_1064b_row8_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1064b_row1_col1, #T_1064b_row1_col2, #T_1064b_row4_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_1064b_row1_col3, #T_1064b_row2_col6 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_1064b_row1_col4 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_1064b_row1_col5 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_1064b_row2_col2, #T_1064b_row3_col1, #T_1064b_row7_col0 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_1064b_row2_col3, #T_1064b_row3_col6 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_1064b_row3_col2, #T_1064b_row6_col1, #T_1064b_row8_col0 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_1064b_row3_col4 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_1064b_row3_col5 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_1064b_row4_col1, #T_1064b_row6_col2, #T_1064b_row9_col0 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_1064b_row4_col3 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_1064b_row4_col4 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_1064b_row5_col0, #T_1064b_row5_col2, #T_1064b_row7_col1 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1064b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1064b_level0_col0" class="col_heading level0 col0" >12-24</th>
#       <th id="T_1064b_level0_col1" class="col_heading level0 col1" >24-36</th>
#       <th id="T_1064b_level0_col2" class="col_heading level0 col2" >36-48</th>
#       <th id="T_1064b_level0_col3" class="col_heading level0 col3" >48-60</th>
#       <th id="T_1064b_level0_col4" class="col_heading level0 col4" >60-72</th>
#       <th id="T_1064b_level0_col5" class="col_heading level0 col5" >72-84</th>
#       <th id="T_1064b_level0_col6" class="col_heading level0 col6" >84-96</th>
#       <th id="T_1064b_level0_col7" class="col_heading level0 col7" >96-108</th>
#       <th id="T_1064b_level0_col8" class="col_heading level0 col8" >108-120</th>
#       <th id="T_1064b_level0_col9" class="col_heading level0 col9" >120-132</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1064b_level0_row0" class="row_heading level0 row0" >1998</th>
#       <td></td>
#       <td></td>
#       <td id="T_1064b_row0_col2" class="data row0 col2" >1.1082</td>
#       <td id="T_1064b_row0_col3" class="data row0 col3" >1.0675</td>
#       <td id="T_1064b_row0_col4" class="data row0 col4" >1.0644</td>
#       <td id="T_1064b_row0_col5" class="data row0 col5" >1.0441</td>
#       <td id="T_1064b_row0_col6" class="data row0 col6" >1.1142</td>
#       <td id="T_1064b_row0_col7" class="data row0 col7" >0.9876</td>
#       <td id="T_1064b_row0_col8" class="data row0 col8" >0.9797</td>
#       <td id="T_1064b_row0_col9" class="data row0 col9" >0.9992</td>
#     </tr>
#     <tr>
#       <th id="T_1064b_level0_row1" class="row_heading level0 row1" >1999</th>
#       <td></td>
#       <td id="T_1064b_row1_col1" class="data row1 col1" >1.2376</td>
#       <td id="T_1064b_row1_col2" class="data row1 col2" >1.1971</td>
#       <td id="T_1064b_row1_col3" class="data row1 col3" >1.1443</td>
#       <td id="T_1064b_row1_col4" class="data row1 col4" >1.0574</td>
#       <td id="T_1064b_row1_col5" class="data row1 col5" >1.0560</td>
#       <td id="T_1064b_row1_col6" class="data row1 col6" >0.9881</td>
#       <td id="T_1064b_row1_col7" class="data row1 col7" >1.0111</td>
#       <td id="T_1064b_row1_col8" class="data row1 col8" >1.0014</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th id="T_1064b_level0_row2" class="row_heading level0 row2" >2000</th>
#       <td id="T_1064b_row2_col0" class="data row2 col0" >1.1960</td>
#       <td id="T_1064b_row2_col1" class="data row2 col1" >1.1681</td>
#       <td id="T_1064b_row2_col2" class="data row2 col2" >1.2395</td>
#       <td id="T_1064b_row2_col3" class="data row2 col3" >1.0864</td>
#       <td id="T_1064b_row2_col4" class="data row2 col4" >1.1685</td>
#       <td id="T_1064b_row2_col5" class="data row2 col5" >1.0723</td>
#       <td id="T_1064b_row2_col6" class="data row2 col6" >1.0150</td>
#       <td id="T_1064b_row2_col7" class="data row2 col7" >0.9931</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th id="T_1064b_level0_row3" class="row_heading level0 row3" >2001</th>
#       <td id="T_1064b_row3_col0" class="data row3 col0" >1.3532</td>
#       <td id="T_1064b_row3_col1" class="data row3 col1" >1.3135</td>
#       <td id="T_1064b_row3_col2" class="data row3 col2" >1.2643</td>
#       <td id="T_1064b_row3_col3" class="data row3 col3" >1.2870</td>
#       <td id="T_1064b_row3_col4" class="data row3 col4" >1.0857</td>
#       <td id="T_1064b_row3_col5" class="data row3 col5" >1.0378</td>
#       <td id="T_1064b_row3_col6" class="data row3 col6" >1.0067</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th id="T_1064b_level0_row4" class="row_heading level0 row4" >2002</th>
#       <td id="T_1064b_row4_col0" class="data row4 col0" >1.5900</td>
#       <td id="T_1064b_row4_col1" class="data row4 col1" >1.3086</td>
#       <td id="T_1064b_row4_col2" class="data row4 col2" >1.4131</td>
#       <td id="T_1064b_row4_col3" class="data row4 col3" >1.1791</td>
#       <td id="T_1064b_row4_col4" class="data row4 col4" >1.0965</td>
#       <td id="T_1064b_row4_col5" class="data row4 col5" >0.9891</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th id="T_1064b_level0_row5" class="row_heading level0 row5" >2003</th>
#       <td id="T_1064b_row5_col0" class="data row5 col0" >1.7610</td>
#       <td id="T_1064b_row5_col1" class="data row5 col1" >1.7861</td>
#       <td id="T_1064b_row5_col2" class="data row5 col2" >1.3374</td>
#       <td id="T_1064b_row5_col3" class="data row5 col3" >1.0896</td>
#       <td id="T_1064b_row5_col4" class="data row5 col4" >1.0032</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th id="T_1064b_level0_row6" class="row_heading level0 row6" >2004</th>
#       <td id="T_1064b_row6_col0" class="data row6 col0" >2.3642</td>
#       <td id="T_1064b_row6_col1" class="data row6 col1" >1.4651</td>
#       <td id="T_1064b_row6_col2" class="data row6 col2" >1.2181</td>
#       <td id="T_1064b_row6_col3" class="data

# %% [markdown]
# Let's get a volume-weighted average LDFs for our Incurred triangle.

# %%
cl.Development(average="volume").fit(xyz_tri["Incurred"]).ldf_
# Out:
#           12-24     24-36     36-48     48-60     60-72     72-84     84-96    96-108   108-120   120-132
# (All)  1.675693  1.339353  1.193406  1.095906  1.076968  1.033612  1.019016  0.997636  0.992918  0.999179

# %% [markdown]
# How about the CDFs? But use a `simple` average instead.

# %%
cl.Development(average="simple").fit(xyz_tri["Incurred"]).cdf_
# Out:
#          12-Ult    24-Ult    36-Ult    48-Ult    60-Ult    72-Ult   84-Ult   96-Ult   108-Ult   120-Ult
# (All)  3.503374  2.111056  1.563004  1.278249  1.142156  1.058237  1.01767  0.98706  0.989758  0.999179

# %% [markdown]
# We can also use only the latest 3 periods in the calculation of CDFs.

# %%
cl.Development(average="simple", n_periods=3).fit(xyz_tri["Incurred"]).cdf_
# Out:
#          12-Ult    24-Ult    36-Ult    48-Ult    60-Ult   72-Ult    84-Ult   96-Ult   108-Ult   120-Ult
# (All)  3.102708  1.857218  1.395977  1.176395  1.086262  1.02303  0.990285  0.98706  0.989758  0.999179

# %% [markdown]
# # Deterministic Models

# %% [markdown]
# Before we can build any models, we need to use `fit_transform()`, so that the object is actually modified with our selected development pattern(s).
#
# Set the development of the triangle to use only 3 periods, calculated using the `simple` method.

# %%
cl.Development(average="simple", n_periods=3).fit_transform(xyz_tri["Incurred"])
# Out:
#           12       24       36       48       60       72       84       96       108      120      132
# 1998      NaN      NaN  11171.0  12380.0  13216.0  14067.0  14688.0  16366.0  16163.0  15835.0  15822.0
# 1999      NaN  13255.0  16405.0  19639.0  22473.0  23764.0  25094.0  24795.0  25071.0  25107.0      NaN
# 2000  15676.0  18749.0  21900.0  27144.0  29488.0  34458.0  36949.0  37505.0  37246.0      NaN      NaN
# 2001  11827.0  16004.0  21022.0  26578.0  34205.0  37136.0  38541.0  38798.0      NaN      NaN      NaN
# 2002  12811.0  20370.0  26656.0  37667.0  44414.0  48701.0  48169.0      NaN      NaN      NaN      NaN
# 2003   9651.0  16995.0  30354.0  40594.0  44231.0  44373.0      NaN      NaN      NaN      NaN      NaN
# 2004  16995.0  40180.0  58866.0  71707.0  70288.0      NaN      NaN      NaN      NaN      NaN      NaN
# 2005  28674.0  47432.0  70340.0  70655.0      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2006  27066.0  46783.0  48804.0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2007  19477.0  31732.0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2008  18632.0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN

# %% [markdown]
# Let's fit a chainladder model to our Incurred triangle.

# %%
cl_mod = cl.Chainladder().fit(xyz_tri["Incurred"])
cl_mod
# Out:
# Chainladder()

# %% [markdown]
# How can we get the model's ultimate estimate?

# %%
cl_mod.ultimate_
# Out:
#               2261
# 1998  15822.000000
# 1999  25086.388001
# 2000  36951.879990
# 2001  38400.613702
# 2002  48582.226476
# 2003  46257.941381
# 2004  78913.510138
# 2005  86933.374265
# 2006  71661.720703
# 2007  62405.722716
# 2008  61401.770743

# %% [markdown]
# How about just the IBNR?

# %%
cl_mod.ibnr_
# Out:
#               2261
# 1998           NaN
# 1999    -20.611999
# 2000   -294.120010
# 2001   -397.386298
# 2002    413.226476
# 2003   1884.941381
# 2004   8625.510138
# 2005  16278.374265
# 2006  22857.720703
# 2007  30673.722716
# 2008  42769.770743

# %% [markdown]
# Let's fit an Expected Loss model, with an aprior of 90% on Premium, and get its ultimates.

# %%
cl.ExpectedLoss(apriori=0.90).fit(
    xyz_tri["Incurred"], sample_weight=xyz_tri["Premium"].latest_diagonal
).ultimate_
# Out:
#           2261
# 1998   18000.0
# 1999   28350.0
# 2000   40500.0
# 2001   45000.0
# 2002   55064.7
# 2003   62257.5
# 2004   89389.8
# 2005  124335.9
# 2006   96820.2
# 2007   56194.2
# 2008   43017.3

# %% [markdown]
# Try it on the Paid triangle, do you get the same ultimate?

# %%
cl.ExpectedLoss(apriori=0.90).fit(
    xyz_tri["Paid"], sample_weight=xyz_tri["Premium"].latest_diagonal
).ultimate_
# Out:
#           2261
# 1998   18000.0
# 1999   28350.0
# 2000   40500.0
# 2001   45000.0
# 2002   55064.7
# 2003   62257.5
# 2004   89389.8
# 2005  124335.9
# 2006   96820.2
# 2007   56194.2
# 2008   43017.3

# %% [markdown]
# How about a Bornhuetter-Ferguson model?

# %%
cl.BornhuetterFerguson(apriori=0.90).fit(
    xyz_tri["Incurred"], sample_weight=xyz_tri["Premium"].latest_diagonal
).ultimate_
# Out:
#               2261
# 1998  15822.000000
# 1999  25083.706485
# 2000  36923.638582
# 2001  38332.320375
# 2002  48637.364535
# 2003  46909.899276
# 2004  80058.603599
# 2005  93937.040205
# 2006  79686.444188
# 2007  59352.628911
# 2008  48595.957663

# %% [markdown]
# How about Benktander, with 1 iteration, which is the same as BF?

# %%
cl.Benktander(apriori=0.90, n_iters=1).fit(
    xyz_tri["Incurred"], sample_weight=xyz_tri["Premium"].latest_diagonal
).ultimate_
# Out:
#               2261
# 1998  15822.000000
# 1999  25083.706485
# 2000  36923.638582
# 2001  38332.320375
# 2002  48637.364535
# 2003  46909.899276
# 2004  80058.603599
# 2005  93937.040205
# 2006  79686.444188
# 2007  59352.628911
# 2008  48595.957663

# %% [markdown]
# How about Cape Cod?

# %%
cl.CapeCod().fit(
    xyz_tri["Incurred"], sample_weight=xyz_tri["Premium"].latest_diagonal
).ultimate_
# Out:
#               2261
# 1998  15822.000000
# 1999  25087.431508
# 2000  36975.189569
# 2001  38406.790341
# 2002  48562.465206
# 2003  46504.206620
# 2004  78496.120544
# 2005  90213.852284
# 2006  74747.824455
# 2007  54935.628037
# 2008  43804.219299

# %% [markdown]
# Let's store the Cape Cod model as `cc_result`. We can also use `.to_frame()` to leave `chainladder` and go to a `DataFrame`. Let's make a bar chart over origin years to see what they look like.

# %%
cc_result = (
    cl.CapeCod()
    .fit(xyz_tri["Incurred"], sample_weight=xyz_tri["Premium"].latest_diagonal)
    .ultimate_
).to_frame()

plt.plot(
    cc_result.index.year, 
    cc_result["2261"]
)

# %% [markdown]
# # Stochastic Models

# %% [markdown]
# The Mack's Chainladder model is available. Let's use it on the Incurred triangle.

# %%
mcl_mod = cl.MackChainladder().fit(xyz_tri["Incurred"])
mcl_mod
# Out:
# MackChainladder()

# %% [markdown]
# There are many attributes that are available, such as `full_std_err_`, `total_process_risk_`, `total_parameter_risk_`, `mack_std_err_` and `total_mack_std_err_`.

# %%
mcl_mod.full_std_err_
# Out:
#            12        24        36        48        60        72        84        96        108       120  132
# 1998  0.000000  0.000000  0.245040  0.174079  0.088551  0.053698  0.060944  0.014560  0.016943  0.010720  0.0
# 1999  0.000000  0.325403  0.202207  0.138212  0.067907  0.041314  0.046626  0.011829  0.013604  0.008513  0.0
# 2000  0.346685  0.273604  0.175009  0.117563  0.059282  0.034309  0.038425  0.009618  0.011162  0.007014  0.0
# 2001  0.399131  0.296140  0.178627  0.118808  0.055043  0.033049  0.037623  0.009456  0.010949  0.006881  0.0
# 2002  0.383496  0.262492  0.158630  0.099799  0.048304  0.028859  0.033653  0.008407  0.009734  0.006117  0.0
# 2003  0.441841  0.287376  0.148654  0.096134  0.048404  0.030234  0.034488  0.008616  0.009976  0.006269  0.0
# 2004  0.332960  0.186899  0.106746  0.072331  0.038398  0.023148  0.026405  0.006597  0.007638  0.004800  0.0
# 2005  0.256335  0.172019  0.097652  0.072868  0.036584  0.022054  0.025158  0.006285  0.007277  0.004573  0.0
# 2006  0.263840  0.173208  0.117235  0.080257  0.040294  0.024291  0.027709  0.006922  0.008015  0.005037  0.0
# 2007  0.311022  0.210311  0.125628  0.086003  0.043178  0.026030  0.029693  0.007418  0.008589  0.005398  0.0
# 2008  0.317997  0.212024  0.126651  0.086704  0.043530  0.026242  0.029935  0.007478  0.008659  0.005441  0.0

# %% [markdown]
# MackChainladder also has a `summary_` attribute.

# %%
mcl_mod.summary_
# Out:
#        Latest          IBNR      Ultimate  Mack Std Err
# 1998  15822.0           NaN  15822.000000           NaN
# 1999  25107.0    -20.611999  25086.388001    343.683099
# 2000  37246.0   -294.120010  36951.879990    743.535220
# 2001  38798.0   -397.386298  38400.613702    886.064123
# 2002  48169.0    413.226476  48582.226476   2185.978873
# 2003  44373.0   1884.941381  46257.941381   2610.763121
# 2004  70288.0   8625.510138  78913.510138   5000.109425
# 2005  70655.0  16278.374265  86933.374265   8483.853790
# 2006  48804.0  22857.720703  71661.720703  10736.822363
# 2007  31732.0  30673.722716  62405.722716  14409.016585
# 2008  18632.0  42769.770743  61401.770743  18903.538131

# %% [markdown]
# Let's make a graph, that shows the Reported and IBNR as stacked bars, and error bars showing Mack Standard Errors.

# %%
plt.bar(
    mcl_mod.summary_.to_frame(origin_as_datetime=True).index.year,
    mcl_mod.summary_.to_frame(origin_as_datetime=True)["Latest"],
    label="Reported",
)
plt.bar(
    mcl_mod.summary_.to_frame(origin_as_datetime=True).index.year,
    mcl_mod.summary_.to_frame(origin_as_datetime=True)["IBNR"],
    bottom=mcl_mod.summary_.to_frame(origin_as_datetime=True)["Latest"],
    yerr=mcl_mod.summary_.to_frame(origin_as_datetime=True)["Mack Std Err"],
    label="IBNR",
)
plt.legend(loc="upper left")

# %% [markdown]
# ODP Bootstrap is also available. Let's build sample 10,000 Incurred triangles.

# %%
xyz_tri_sampled = (
    cl.BootstrapODPSample(n_sims=10000).fit(xyz_tri["Incurred"]).resampled_triangles_
)
xyz_tri_sampled
# Out:
#               Triangle Summary
# Valuation:             2008-12
# Grain:                    OYDY
# Shape:      (10000, 1, 11, 11)
# Index:                 [Total]
# Columns:            [Incurred]

# %% [markdown]
# We can fit a basic chainladder to all sampled triangles. We now have 10,000 simulated chainladder models, all (most) with unique LDFs.

# %%
cl_mod_bootstrapped = cl.Chainladder().fit(xyz_tri_sampled)
cl_mod_bootstrapped
# Out:
# /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages/chainladder/utils/weighted_regression.py:84: RuntimeWarning: invalid value encountered in sqrt
#   residual = (y - fitted_value) * xp.sqrt(w)
# /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages/chainladder/development/development.py:173: RuntimeWarning: invalid value encountered in sqrt
#   / xp.swapaxes(xp.sqrt(x ** (2 - exponent))[..., 0:1, :], -1, -2)
# /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages/chainladder/development/development.py:182: RuntimeWarning: invalid value encountered in sqrt
#   std = xp.sqrt((1 / num_to_nan(w)) * (self.sigma_**2).values)
# /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages/chainladder/tails/base.py:120: RuntimeWarning: overflow encountered in exp
#   sigma_ = xp.exp(time_pd * reg.slope_ + reg.intercept_)
# /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages/chainladder/tails/base.py:124: RuntimeWarning: overflow encountered in exp
#   std_err_ = xp.exp(time_pd * reg.slope_ + reg.intercept_)
# /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages/chainladder/tails/base.py:127: RuntimeWarning: invalid value encountered in multiply
#   sigma_ = sigma_ * 0
# /Users/kennethhsu/opt/anaconda3/lib/python3.9/site-packages/chainladder/tails/base.py:128: RuntimeWarning: invalid value encountered in multiply
#   std_err_ = std_err_* 0
# Chainladder()

# %% [markdown]
# Let's make another graph.

# %%
plt.bar(
    cl_mod_bootstrapped.ultimate_.mean().to_frame(origin_as_datetime=True).index.year,
    cl_mod_bootstrapped.ultimate_.mean().to_frame(origin_as_datetime=True)["2261"],
    yerr=cl_mod_bootstrapped.ultimate_.std().to_frame(origin_as_datetime=True)["2261"],
)
# Out:
# <BarContainer object of 11 artists>
